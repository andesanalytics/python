# %% [markdown]
# # Clase 2: Manipulación de Datos

# %% [markdown]
# # **Repaso Clase 1 Pandas**

# %%
# Preparar el Entorno
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Librería Pandas
import pandas as pd

# %%
# Cargar la BBDD
df = pd.read_csv('/content/drive/MyDrive/base_seguros.csv')

# %%
# Visualizar las primeras 4 filas de la BBDD, recordar que head es un método por eso está asociado a un objeto, en este cado df
df.head(4)
# Out:
#    ID  age     gender  years.in.company         insurance.type custcomer.type  \
# 0   0   48  masculino                 2  Accidentes Personales         Normal
# 1   1   48  masculino                 2  Accidentes Personales        Premium
# 2   2   58   femenino                 5  Accidentes Personales        Premium
# 3   3   64  masculino                 5  Accidentes Personales         Normal
#
#   region  city  premium.coverage.A  premium.coverage.B
# 0     II    20                2.80                0.47
# 1     IX    44                2.88                0.48
# 2     IV    42                1.33                0.37
# 3    VII    49                2.03                0.39

# %%
#Me entrega estadística descriptiva
df.describe()
# Out:
#                   ID            age  years.in.company           city  \
# count  104670.000000  104670.000000     104670.000000  104670.000000
# mean    52334.500000      40.976354          5.005599      25.015640
# std     30215.770675      13.548700          2.239304      14.151252
# min         0.000000      18.000000          0.000000       1.000000
# 25%     26167.250000      29.000000          3.000000      13.000000
# 50%     52334.500000      41.000000          5.000000      25.000000
# 75%     78501.750000      53.000000          6.000000      37.000000
# max    104669.000000      64.000000         16.000000      49.000000
#
#        premium.coverage.A  premium.coverage.B
# count       104670.000000       104670.000000
# mean             1.999508            0.500028
# std              0.500779            0.100271
# min             -0.060000            0.090000
# 25%              1.660000            0.430000
# 50%              2.000000            0.500000
# 75%              2.340000            0.570000
# max              4.090000            0.930000

# %%
# Este es un atributo, por eso no lleva parentesis
df.shape
# Out:
# (104670, 10)

# %%
# Me entrega información básica de la BBDD
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104670 entries, 0 to 104669
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID                  104670 non-null  int64
#  1   age                 104670 non-null  int64
#  2   gender              104670 non-null  object
#  3   years.in.company    104670 non-null  int64
#  4   insurance.type      104670 non-null  object
#  5   custcomer.type      104670 non-null  object
#  6   region              104670 non-null  object
#  7   city                104670 non-null  int64
#  8   premium.coverage.A  104670 non-null  float64
#  9   premium.coverage.B  104670 non-null  float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 8.0+ MB

# %% [markdown]
# # **Indexación en Pandas**

# %% [markdown]
# **Acceso a los elementos de un DataFrame**
# El acceso a los datos de un DataFrame se puede hacer a travész de posiciones o através de los nombres de las filas y columnas
#
# 1. Acceso mediante posiciones
# * `df.iloc[i, j]` : Devuelve el elemento que se encuentra en la fila i y la columna j del DataFrame df. Pueden indicarse secuencias de índices para obtener partes del DataFrame.
#
# * `df.iloc[filas, columnas]` : Devuelve un DataFrame con los elementos de las filas de la lista filas y de las columnas de la lista columnas.
#
# * `df.iloc[i]` : Devuelve una serie con los elementos de la fila i del DataFrame df

# %%
# Acceder a la posición
df.iloc[1000, 9]
#Acceder a un sector del DataFrame, porque Pandas no incluye el último argumento de una tupla 1:4 = [1,4)
df.iloc[1:10, 2:6]
# Acceder a un serie de la fila 8
df.iloc[8]
# Out:
# ID                            8
# age                          52
# gender                masculino
# years.in.company              4
# insurance.type             Vida
# custcomer.type          Premium
# region                      VII
# city                         37
# premium.coverage.A         1.07
# premium.coverage.B         0.59
# Name: 8, dtype: object

# %% [markdown]
# 2. Acceso mediante nombres de filas y columnas
#
# * `df.loc[fila, columna]` : Devuelve el elemento que se encuentra en la fila con nombre fila y la columna de con nombre columna del DataFrame df.
#
# * `df[columna]` : Devuelve una serie con los elementos de la columna de nombre columna del DataFrame df.
#
# * `df.columna` : Devuelve una serie con los elementos de la columna de nombre columna del DataFrame df. Es similar al método anterior pero solo funciona cuando el nombre de la columna no tiene espacios en blanco.

# %%
# Esto se utiliza para acceder a una celda, conociendo el nombre de la fila y columna
df.loc[1,'gender']
# Esto se utiliza para extraer la columna genero
df['gender']
# Forma 2
df.gender
# Out:
# 0         masculino
# 1         masculino
# 2          femenino
# 3         masculino
# 4          femenino
#             ...
# 104665    masculino
# 104666     femenino
# 104667     femenino
# 104668    masculino
# 104669     femenino
# Name: gender, Length: 104670, dtype: object

# %% [markdown]
# **Ejemplo:** Usando la misma BBDD del ejercicio anterior
#
# 1. Indexar solo la columna age.
# 2. Indexar las primeras 10 filas de la columna gender

# %%
#Solución 1
df['age']
# Out:
# 0         48
# 1         48
# 2         58
# 3         64
# 4         56
#           ..
# 104665    60
# 104666    28
# 104667    26
# 104668    41
# 104669    26
# Name: age, Length: 104670, dtype: int64

# %%
# Solución 2

#Forma 1
df.loc[0:9,'gender']
#Forma 2
df.iloc[0:10,2]
#Forma 3: Más óptima
df.gender.head(10)
# Out:
# 0    masculino
# 1    masculino
# 2     femenino
# 3    masculino
# 4     femenino
# 5     femenino
# 6     femenino
# 7     femenino
# 8    masculino
# 9     femenino
# Name: gender, dtype: object

# %% [markdown]
# **Operaciones con las columnas de un DataFrame**
# 1. Añadir columnas
# `df[nombre]`= lista: Si no existe la columna cuyo nombre sea "nombre" automáticamente se genera. el tamaño de la lista debe ser igual al largo de la columna
# 2. Eliminar columnas
# `del df[nombre]`: Elimina la columna con nombre "nombre" del DataFrame
# 4. Aplicar funciones a columnas
# `df[nombre].apply(f)`: Devuelve una serie con los valores que resulta de aplicar la función f a los elementos de la columna con nombre "nombre" del DataFrame df
# 5. Convertir una columna
# * `to_datetime(columna, formato)`: Devuelve la serie que resulta de convertir las cadenas de la columna con el nombre columna en fechas del tipo datetime con el formato indicado. Existen más tipos de cambios.
# * `to_numeric(columna)`: Convierte el objeto a números. Útil para convertir strings numércios a tipo de datos numéricos
# * `to_categorical(columna)`: Convierte la columna a una categoría.
#
# **Operaciones con las filas de un DataFrame**
# 1. Añadir una fila
# `df.append(serie, ignore_index = True)`: Devuelve el DataFrame que resulta de añadir una fila al DataFrame df con los valores de la serie .
# 2. Eliminar una fila
# `df.drop(filas)`: Devuelve el DataFrame que resulta de eliminar las filas con los nombres indicados en la lista
# 3. Filtrar filas
# `df[condicion]`: Devuleve un DataFrame con las filas del DataFrame df que corresponden con el valor True de la lista.
# 4. Ordenar un DataFrame
# * `df.sort_values(columna, ascending = True)`: DEvuelve el DataFrame que resulta de ordenar las filas del DataFrame df según los vaores de la columna con nombre columna.
# * `df.sort_index(ascending = True)`: Devuelve el DataFrame que resulta de ordenar las filas del DataFrame df según los nombres de las filas.
# 5. Agrupar filas basadas en los valores de una o más columnas. Esto significa que estás organizando las filas en grupos según ciertos criterios definidos por los valores de las columnas
# * `df.groupby(columna)`
# 6. Operaciones de agregación en grupos de datos generados por `group_by` la sintaxis básica es la siguiente
# * `df.group_by(columna).agg(funciones)`

# %% [markdown]
# ## Ejercicio 1
#
# 1. **Crear un DataFrame** con información de seguros de vida y automóviles. Incluye columnas como "Tipo de seguro", "Monto asegurado", "Prima anual", y "Fecha de vencimiento".

# %%
#Crear un diccionario
data = {
    'Tipo de seguro': ["Vida", "Atomóvil", "Vida", 'Automóvil'],
    "Monto asegurado (M)": [150, 80, 2000, 120],
    'Prima Anual (M)': [1.5, 1,1.8, 1.1],
    'Fecha Vencimiento': ["2024-12-31","2024-06-30", "2024-11-30", "2024-09-30"]
}

# %%
# Transformar el Diccionario en DataFrame
df1 = pd.DataFrame(data)

# %% [markdown]
# 2. Mostrar la información de los seguros cuyo monto asegurado sea superior a $100,000.

# %%
df2 = df1[df1['Monto asegurado (M)'] > 100]
# Out:
#   Tipo de seguro  Monto asegurado (M)  Prima Anual (M) Fecha Vencimiento
# 0           Vida                  150              1.5        2024-12-31
# 2           Vida                 2000              1.8        2024-11-30
# 3      Automóvil                  120              1.1        2024-09-30

# %% [markdown]
# 3. Calcular el promedio de la prima anual para todos los seguros.

# %%
# Forma 1:
df1['Prima Anual (M)'].mean()

# Forma 2:
df1['Prima Anual (M)'].apply(lambda x: x).mean()

#Donde usar apply: Transformar la prima anual en miles a una prima mensual en CLP
df1['Prima Anual (M)'].apply(lambda x: (x/12)*1000)
# Out:
# 0    125.000000
# 1     83.333333
# 2    150.000000
# 3     91.666667
# Name: Prima Anual (M), dtype: float64

# %% [markdown]
# 4. Agregar una nueva columna llamada "Descuento" que represente un descuento del 10% en la prima anual.

# %%
df1['Descuento (M)'] = df1['Prima Anual (M)'].apply(lambda x: x * 0.1)

# %%
# Miremos el DataFrame
df1.head(5)
# Out:
#   Tipo de seguro  Monto asegurado (M)  Prima Anual (M) Fecha Vencimiento  \
# 0           Vida                  150              1.5        2024-12-31
# 1       Atomóvil                   80              1.0        2024-06-30
# 2           Vida                 2000              1.8        2024-11-30
# 3      Automóvil                  120              1.1        2024-09-30
#
#    Descuento (M)
# 0           0.15
# 1           0.10
# 2           0.18
# 3           0.11
