# %%
#Importar Librerías

import pandas as pd
import datetime as dt
from google.colab import files

# %%
# Subir el archivo al Sistema Local
fd_up = files.upload()
# Out:
#      <input type="file" id="files-9406bc1b-25d9-4750-8c52-0f2d43c31e53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9406bc1b-25d9-4750-8c52-0f2d43c31e53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Cargar BBDD
df = pd.read_excel('/content/Seguros_Auto.xlsx', sheet_name = 'Datos Extras')

# %%
# Head ayuda a una visualización rápida
df.tail()
# Info me ayuda a confirmar el tipo de objeto de las columnas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID Mónaco         2573 non-null   int64
#  1   FECHA_PAGARE      2572 non-null   datetime64[ns]
#  2   Fecha de Termino  2573 non-null   datetime64[ns]
#  3   Plazo             2573 non-null   int64
# dtypes: datetime64[ns](2), int64(2)
# memory usage: 80.5 KB

# %%
# La fecha al usar strftime se convierte en un objeto de tipo str
df['FECHA_PAGARE'] = df['FECHA_PAGARE'].dt.strftime('%Y-%m-%d')
# Para convertir un str a fecha se usa to_datetime()
df['FECHA_PAGARE'] = pd.to_datetime(df['FECHA_PAGARE'])

# %%
# Calcular el plazo total del seguro, es decir, desde que fue contratado, hasta que termino
df['Dif'] = df['Fecha de Termino'] - df['FECHA_PAGARE']
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID Mónaco         2573 non-null   int64
#  1   FECHA_PAGARE      2572 non-null   datetime64[ns]
#  2   Fecha de Termino  2573 non-null   datetime64[ns]
#  3   Plazo             2573 non-null   int64
#  4   Dif               2572 non-null   timedelta64[ns]
#  5   DIF Meses         2572 non-null   timedelta64[ns]
# dtypes: datetime64[ns](2), int64(2), timedelta64[ns](2)
# memory usage: 120.7 KB

# %%
#Queremos crear una columna que se llame Dif meses y que convierta la Diferencia en dias en meses
df['DIF Meses'] = df['Dif']/30.44
# Out:
#    ID Mónaco FECHA_PAGARE Fecha de Termino  Plazo      Dif  \
# 0    1959375   2022-05-12       2023-11-05     17 542 days
# 1    1967037   2022-05-26       2023-06-05     12 375 days
# 2    1928319   2022-05-02       2023-05-10     12 373 days
# 3    1961495   2022-05-16       2024-04-30     24 715 days
# 4    1943825   2022-05-10       2023-05-05     12 360 days
#
#                    DIF Meses
# 0 17 days 19:19:56.846254927
# 1 12 days 07:39:48.961892247
# 2 12 days 06:05:12.220762155
# 3 23 days 11:43:54.954007884
# 4 11 days 19:50:13.403416557

# %%
df_Multi = pd.read_excel('/content/Seguros_Auto.xlsx', sheet_name= 'Plazo MultiAsistencia')
df_Multi.head()
df_Multi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fecha Curse       430 non-null    datetime64[ns]
#  1   Periodo           430 non-null    float64
#  2   ID Mónaco         430 non-null    float64
#  3   Monto Asistencia  430 non-null    float64
#  4   Plazo             430 non-null    float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 20.1 KB

# %%
# Unir dos BBDD
df_full = pd.merge(df,
                   df_Multi,
                   on = 'ID Mónaco',
                   how = 'right')

df_full = df_full[['ID Mónaco', 'FECHA_PAGARE','Fecha de Termino', 'Plazo_x', 'Periodo', 'Monto Asistencia']]
df_full.rename(columns = {'Plazo_x': 'Plazo'}, inplace = True)
df_full.head()
# Out:
#    ID Mónaco FECHA_PAGARE Fecha de Termino  Plazo   Periodo  Monto Asistencia
# 0  1928319.0   2022-05-02       2023-05-10   12.0  202205.0           83764.0
# 1  1943825.0   2022-05-10       2023-05-05   12.0  202205.0           84133.0
# 2  1938951.0   2022-05-05       2023-12-01   18.0  202205.0          122655.0
# 3  1967035.0   2022-05-24       2023-12-01   18.0  202205.0          124000.0
# 4  1929399.0   2022-05-02       2025-08-05   39.0  202205.0          153289.0

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512 entries, 0 to 511
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID Mónaco         430 non-null    float64
#  1   FECHA_PAGARE      430 non-null    datetime64[ns]
#  2   Fecha de Termino  430 non-null    datetime64[ns]
#  3   Plazo             430 non-null    float64
#  4   Periodo           430 non-null    float64
#  5   Monto Asistencia  430 non-null    float64
# dtypes: datetime64[ns](2), float64(4)
# memory usage: 28.0 KB

# %%
# ¿En qué periodo los seguros tiene un valor mayor?
df_full.groupby('Periodo').mean()

#Primero hay solomun periodo, en este periodo los seguros tienen un valor promedio de $244.853 y el plazo promedio son 39 meses de vigencia.
# Out:
# <ipython-input-52-79a1ade3b20f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_full.groupby('Periodo').mean()
#              ID Mónaco      Plazo  Monto Asistencia
# Periodo
# 202205.0  1.948565e+06  39.386047     244853.525581

# %%
df_full['Monto Asistencia'].max()
df_full['Monto Asistencia'].describe()
# Out:
# count       430.000000
# mean     244853.525581
# std       75866.632938
# min       83292.000000
# 25%      162520.000000
# 50%      246367.500000
# 75%      317684.000000
# max      398154.000000
# Name: Monto Asistencia, dtype: float64

# %%
#Unir BBDD
df_left = pd.merge(df,
                df_Multi,
                on ='ID Mónaco',
                how = 'left')
df_left = df_left[['ID Mónaco', 'FECHA_PAGARE','Fecha de Termino', 'Plazo_x', 'Periodo', 'Monto Asistencia']]
df_left.rename(columns = {'Plazo_x': 'Plazo'}, inplace = True)
df_left.head()
# Out:
#    ID Mónaco FECHA_PAGARE Fecha de Termino  Plazo   Periodo  Monto Asistencia
# 0    1959375   2022-05-12       2023-11-05     17       NaN               NaN
# 1    1967037   2022-05-26       2023-06-05     12       NaN               NaN
# 2    1928319   2022-05-02       2023-05-10     12  202205.0           83764.0
# 3    1961495   2022-05-16       2024-04-30     24       NaN               NaN
# 4    1943825   2022-05-10       2023-05-05     12  202205.0           84133.0

# %%
#Rellenar los datos faltanes de Periodo con el periodo exacto
df_left.info()
df_left['Periodo'] = df_left['FECHA_PAGARE'].dt.strftime('%Y-%m')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2573 entries, 0 to 2572
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID Mónaco         2573 non-null   int64
#  1   FECHA_PAGARE      2572 non-null   datetime64[ns]
#  2   Fecha de Termino  2573 non-null   datetime64[ns]
#  3   Plazo             2573 non-null   int64
#  4   Periodo           2572 non-null   object
#  5   Monto Asistencia  430 non-null    float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(1)
# memory usage: 140.7+ KB

# %%
# Rellene los datos faltantes de monto asistencia con 0
df_left.head()
df_left.fillna(0)
# Out:
#       ID Mónaco         FECHA_PAGARE Fecha de Termino  Plazo  Periodo  \
# 0       1959375  2022-05-12 00:00:00       2023-11-05     17  2022-05
# 1       1967037  2022-05-26 00:00:00       2023-06-05     12  2022-05
# 2       1928319  2022-05-02 00:00:00       2023-05-10     12  2022-05
# 3       1961495  2022-05-16 00:00:00       2024-04-30     24  2022-05
# 4       1943825  2022-05-10 00:00:00       2023-05-05     12  2022-05
# ...         ...                  ...              ...    ...      ...
# 2568    1972219  2022-05-30 00:00:00       2026-07-05     48  2022-05
# 2569    1972220  2022-05-30 00:00:00       2025-06-02     36  2022-05
# 2570    1972222  2022-05-30 00:00:00       2027-06-07     60  2022-05
# 2571    1972223  2022-05-30 00:00:00       2025-07-01     37  2022-05
# 2572    1972224  2022-05-30 00:00:00       2025-07-05     37  2022-05
#
#       Monto Asistencia
# 0                  0.0
# 1                  0.0
# 2              83764.0
# 3                  0.0
# ...

# %%
# 1.- Asumiremos que si no esta en la BBDD de multiasistencia, no tiene seguro de multiasistencia, es decir,
#completarmos los valores NaN de la columna Monsto Asistencia con 0

#df_left.fillna(0, inplace = True)
#df_left.head()
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 2568   NaN
# 2569   NaN
# 2570   NaN
# 2571   NaN
# 2572   NaN
# Name: FECHA_PAGARE, Length: 2573, dtype: float64
